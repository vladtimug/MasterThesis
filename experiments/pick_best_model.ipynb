# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
carthesian_unet_metrics = pd.read_csv("../experiments_data/set_3_1/experiment_1/test_results_3DIRCADB_Positive/test_metrics.csv")
polar_unet_metrics = pd.read_csv("../experiments_data/set_3_1/experiment_2/test_results_3DIRCADB_Positive/test_metrics.csv")

carthesian_unetpp_metrics = pd.read_csv("../experiments_data/set_4_1/experiment_1/test_results_3DIRCADB_Positive/test_metrics.csv")
polar_unetpp_metrics = pd.read_csv("../experiments_data/set_4_1/experiment_2/test_results_3DIRCADB_Positive/test_metrics.csv")

carthesian_deeplabv3p_metrics = pd.read_csv("../experiments_data/set_6_1/experiment_1/test_results_3DIRCADB_Positive/test_metrics.csv")
polar_deeplabv3p_metrics = pd.read_csv("../experiments_data/set_6_1/experiment_2/test_results_3DIRCADB_Positive/test_metrics.csv")

# %%
plt.figure(figsize=(8, 5))
plt.plot(polar_unet_metrics["test_dice"], label="classic unet")
plt.plot(polar_unetpp_metrics["test_dice"], label="unet++")
plt.plot(polar_deeplabv3p_metrics["test_dice"], label="deeplabv3+")
plt.title("Polar Models Comparison")
plt.xlabel("Volume ID")
# plt.xticks(carthesian_unet_metrics["volume"])
plt.ylabel("Metric Magnitude")
plt.legend()
